# %%
# Import modules
from logger import setup_custom_logger
import sys
import pandas as pd    
import cbsodata
import datetime

# %%
# Setup of logger
try:
    logger = setup_custom_logger("E004_Households_Consumption")
    logger.info('starting')
except:
    logger.exception('logger could not be loaded')
    raise
# Out:
# 2021-03-26 12:07:04 INFO     E004_Households_Consumption starting
# INFO:E004_Households_Consumption:starting

# %%
try:
    # Get current date information
    now = datetime.datetime.now()
    
    logger.info('datetime loaded')
    yearMin = now.year-6
    currentYear = now.year-1
    
    # Values you can load
    # now.year
    # now.month
    # now.day
    # now.hour
    # now.minute
except:
    logger.exception('datetime could not be loaded')
    logger.info('set yearmin to a default value')
    # Set default values for fallback
    yearMin = 2010
    yearMax = 2030
    raise
# Out:
# 2021-03-26 12:07:04 INFO     E004_Households_Consumption datetime loaded
# INFO:E004_Households_Consumption:datetime loaded

# %%
# Dataset 84106NED
dataset_id = '84106NED'

# Table definitions
# Consumptieve Huishoudens: Huishoudens_10 
# SoortMutaties: A045303 = Prijs_tov_zelfde_periode_vorig_jaar
# SoortMutaties: A045299 = Volume_tov_zelfde_periode_vorig_jaar
# SoortMutaties: A045300 = Volume_tov_voorgaande_periode
# SoortMutaties: A045301 = Waarde_tov_zelfe_periode_vorig_jaar
# SoortMutaties: A045302 = Waarde_tov_voorgaande_periode

# %%
try:
    logger.info(f'Retrieve data from dataset {dataset_id}')
    df = pd.DataFrame(cbsodata.get_data(
    f'{dataset_id}',
    filters=f"substring(Perioden,0,4) ge '{yearMin}' and SoortMutaties eq 'A045303' or SoortMutaties eq 'A045299'",
    select=["Perioden", "SoortMutaties",   "Huishoudens_10"]))
except:
    logger.exception('error loading data from CBS Statline')
    raise
# Out:
# 2021-03-26 12:07:04 INFO     E004_Households_Consumption Retrieve data from dataset 84106NED
# INFO:E004_Households_Consumption:Retrieve data from dataset 84106NED

# %%
# Remove  yearly data
try:
    df = df[df['Perioden'].map(len) > 4 ]
except:
    logger.exception('Perioden filter could not be applied')
    raise

# %%
# Date formatting and quarter format
try:
    df["Perioden"] = df["Perioden"].str.replace(" 1e kwartaal", "-03-01")
    df["Perioden"] = df["Perioden"].str.replace(" 2e kwartaal", "-06-01")
    df["Perioden"] = df["Perioden"].str.replace(" 3e kwartaal", "-09-01")
    df["Perioden"] = df["Perioden"].str.replace(" 4e kwartaal", "-12-01")
    df['Perioden'] = pd.to_datetime(df["Perioden"]).dt.date
except:
    logger.exception('Columns could not be changed to monthly numbers or formatted to different date')
    raise

# %%
df
# Out:
#       Perioden                             SoortMutaties  Huishoudens_10
# 0   2015-03-01  Volume, t.o.v. zelfde periode vorig jaar             1.9
# 1   2015-06-01  Volume, t.o.v. zelfde periode vorig jaar             2.2
# 2   2015-09-01  Volume, t.o.v. zelfde periode vorig jaar             2.3
# 3   2015-12-01  Volume, t.o.v. zelfde periode vorig jaar             1.5
# 5   2016-03-01  Volume, t.o.v. zelfde periode vorig jaar             0.9
# 6   2016-06-01  Volume, t.o.v. zelfde periode vorig jaar             0.5
# 7   2016-09-01  Volume, t.o.v. zelfde periode vorig jaar             1.2
# 8   2016-12-01  Volume, t.o.v. zelfde periode vorig jaar             1.9
# 10  2017-03-01  Volume, t.o.v. zelfde periode vorig jaar             1.9
# 11  2017-06-01  Volume, t.o.v. zelfde periode vorig jaar             2.6
# 12  2017-09-01  Volume, t.o.v. zelfde periode vorig jaar             2.8
# 13  2017-12-01  Volume, t.o.v. zelfde periode vorig jaar             1.2
# 15  2018-03-01  Volume, t.o.v. zelfde periode vorig jaar             2.9
# 16  2018-06-01  Volume, t.o.v. zelfde periode vorig jaar             2.4
# 17  2018-09-01  Volume, t.o.v. zelfde periode vorig jaar             1.5
# 18  2018-12-01  Volume, t.o.v. zelfde periode vorig jaar             1.9
# 20  2019-03-01  Volume, t.o.v. zelfde periode vorig jaar             0.9
# 21  2019-06-01  Volume, t.o.v. zelfde periode vorig jaar             1.6
# 22  2019-09-01  Volume, t.o.v. zelfde periode vorig jaar             1.5
# 23  2019-12-01  Volume, t.o.v. zelfde periode vorig jaar             2.0
# 25  2020-03-01  Volume, t.o.v. zelfde periode vorig jaar            -1.1
# 26  2020-06-01  Volume, t.o.v. zelfde periode vorig jaar           -12.6
# 27  2020-09-01  Volume, t.o.v. zelfde periode vorig jaar            -4.9
# 28  2020-12-01  Volume, t.o.v. zelfde periode vorig jaar            -7.0
# 30  2015-03-01   Prijs, t.o.v. zelfde periode vorig jaar            -0.9
# 31  2015-06-01   Prijs, t.o.v. zelfde periode vorig jaar             0.3
# 32  2015-09-01   Prijs, t.o.v. zelfde periode vorig jaar             0.7
# 33  2015-12-01   Prijs, t.o.v. zelfde periode vorig jaar             0.5
# 35  2016-03-01   Prijs, t.o.v. zelfde periode vorig jaar             1.1
# 36  2016-06-01   Prijs, t.o.v. zelfde periode vorig jaar             0.3
# 37  2016-09-01   Prijs, t.o.v. zelfde periode vorig jaar             0.1
# 38  2016-12-01   Prijs, t.o.v. zelfde periode vorig jaar             0.7
# 40  2017-03-01   Prijs, t.o.v. zelfde periode vorig jaar             1.4
# 41  2017-06-01   Prijs, t.o.v. zelfde periode vorig jaar             1.2
# 42  2017-09-01   Prijs, t.o.v. zelfde periode vorig jaar             1.6
# 43  2017-12-01   Prijs, t.o.v. zelfde periode vorig jaar             1.4
# 45  2018-03-01   Prijs, t.o.v. zelfde periode vorig jaar             1.9
# 46  2018-06-01   Prijs, t.o.v. zelfde periode vorig jaar             2.1
# 47  2018-09-01   Prijs, t.o.v. zelfde periode vorig jaar             2.3
# 48  2018-12-01   Prijs, t.o.v. zelfde periode vorig jaar             2.4
# 50  2019-03-01   Prijs, t.o.v. zelfde periode vorig jaar             2.5
# 51  2019-06-01   Prijs, t.o.v. zelfde periode vorig jaar             2.2
# 52  2019-09-01   Prijs, t.o.v. zelfde periode vorig jaar             2.4
# 53  2019-12-01   Prijs, t.o.v. zelfde periode vorig jaar             2.3
# 55  2020-03-01   Prijs, t.o.v. zelfde periode vorig jaar             1.9
# 56  2020-06-01   Prijs, t.o.v. zelfde periode vorig jaar             1.7
# 57  2020-09-01   Prijs, t.o.v. zelfde periode vorig jaar             0.7
# 58  2020-12-01   Prijs, t.o.v. zelfde periode vorig jaar             1.4

# %%
try:
    df.to_csv("output/E004_Households_Consumption.csv")
except:
    logger.exception('Exporting failed')
    raise
